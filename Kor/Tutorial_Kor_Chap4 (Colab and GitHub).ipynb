# %% [markdown]
# <h1>Tutorial: Fancy Tools for Exploring Data Science with Python</h1>

# %% [markdown]
# *Colab에서 열어보려면 뱃지를 클릭하세요!*
# <a href="https://colab.research.google.com/github/teboozas/python_tutorial_for_data_science/Kor/blob/master/Tutorial_Kor_Chap4 (Colab and GitHub).ipynb" target="_parent"><img align="top" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 4. GitHub과 Colab(Jupyter Notebook) 같이 쓰기

# %% [markdown]
# GitHub은 데이터 과학에 대단히 유용한 서비스입니다. 많은 데이터 과학자들이 연구 결과물을 GitHub을 통해 공유하고 있으며, Colab을 사용하면 그 결과물에 쉽게 접근하고 활용할 수 있게 됩니다.
#
# 여기서는 Colab과 GitHub을 함께 사용하는 방법을 간단히 알아볼 예정이며, GitHub과 Git에 대한 자세한 내용은 [이 곳](https://github.com/teboozas/lab_seminar/blob/master/190819_GitHub_Git/slide.pdf), 또는 [GitHub official guide](https://guides.github.com/activities/hello-world/)를 참고하시기 바랍니다.

# %% [markdown]
# ### 4.1 Github repository 복사(clone)하기

# %% [markdown]
# Python 프로그래머들은 작성한 코드와 데이터셋을 대부분 Github의 repository에 보관 및 배포합니다.
#
# Google Colab은 Jupyter Notebook 환경에서 제공하는 clone 명령어를 지원하며, repository를 clone하면 그 안에 포함된 패키지와 모듈, 데이터를 내 디렉토리와 같이 사용할 수 있습니다.

# %%
# 주교재 저자의 Github repository를 clone하는 예시입니다.
# 'PythonDataScienceHandbook'이라는 폴더가 Colab 디렉토리에 새로 생성된 것을 확인할 수 있습니다.

# %cd /content
# !git clone https://github.com/jakevdp/PythonDataScienceHandbook

# %% [markdown]
# ### 4.2 Github에 저장된 `.ipynb` 파일 오픈하기

# %% [markdown]
# Github과 Colab은 직접 연동하여 사용할수도 있습니다.
#
# Github repository에 저장된 `.ipynb`코드를 url을 통해 불러올 수 있고, 실습 모드에서 바로 코드 실행이 가능하여 학습에 대단히 유리합니다.
#
# 실행 방법은 Colab을 오픈하여 Github 탭에서 바로 url을 입력하거나, '파일'의 '노트 열기' 명령어로 실행할수도 있습니다.
#
# 실습을 위해 DQN이 구현된 repository를 방문하고, 코드를 실행해보도록 하겠습니다.
# (url - https://github.com/Curt-Park/rainbow-is-all-you-need)
#
# > **파일 → 노트 열기... → GITHUB → GitHub repository url 입력 → Enter키 입력 → 원하는 .ipynb 파일 열기**

# %% [markdown]
# ### 4.3 Github에 Jupyter Notebook 파일 저장하기

# %% [markdown]
# GitHub 계정에 로그인되어 있다면 Colab에서 작업한 `.ipynb` 파일을 바로 commit(저장)할 수 있습니다.
#
# > **파일 → GitHub에 사본 저장... → 설정 후 '확인' 버튼 클릭**
